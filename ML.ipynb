# %%
import pandas as pd

# %%
# Feature Engineering ---- Data clean and Preprocess

# %%
# workflow of ML ----
# Data Ingrstion ---- Data cleaning and preprocoessing ---- select ML Model --- model traning ---- model evvalation

# %%
# Data dividation
# data --- x,y
# x = x_train , x_test
#  y = y_train , y_test

# %%
# df = pd.read_csv("/content/placement -.csv")
# df.head(2)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0

# %%
# df.shape
# Out:
# (100, 3)

# %%
# x = df.drop(columns=['placed']) ### input data
# x

# %%
# x.shape
# Out:
# (100, 2)

# %%
# y = df['placed']
# y

# %%
# y.shape
# Out:
# (100,)

# %%
# from sklearn.model_selection import train_test_split

# %%
# x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# test = 20%
# train = 80%

# %%
# x_train
# Out:
#     cgpa  resume_score
# 55  6.94          6.87
# 88  8.07          6.07
# 26  6.27          6.47
# 42  6.90          6.91
# 69  8.06          9.06
# ..   ...           ...
# 60  5.87          6.64
# 71  7.34          8.22
# 14  7.51          6.25
# 92  5.43          6.18
# 51  6.54          7.39
#
# [80 rows x 2 columns]

# %%
# x_test
# Out:
#     cgpa  resume_score
# 83  7.60          8.08
# 53  6.00          7.16
# 70  7.12          7.41
# 45  8.10          5.44
# 44  5.47          5.92
# 39  7.50          6.19
# 22  6.16          5.77
# 80  7.83          7.70
# 10  6.18          6.35
# 0   8.14          6.52
# 18  5.94          5.88
# 30  7.36          7.15
# 73  5.76          6.48
# 33  8.43          7.73
# 90  5.85          5.56
# 4   7.52          7.30
# 76  9.40          5.50
# 77  5.88          6.92
# 12  6.09          7.01
# 31  5.92          7.02

# %%
# print("Data shape :" , df.shape)
# print("-----------------")
# print("x data shape :" , x.shape)
# print("x_train data shape: " , x_train.shape)
# print("x_test data shape: " , x_test.shape)
# print("---------------------")
# print("y data shape :" , y.shape)
# print("y_train data shape: " , y_train.shape)
# print("y_test data shape: " , y_test.shape)
# Out:
# Data shape : (100, 3)
# -----------------
# x data shape : (100, 2)
# x_train data shape:  (80, 2)
# x_test data shape:  (20, 2)
# ---------------------
# y data shape : (100,)
# y_train data shape:  (80,)
# y_test data shape:  (20,)

# %%
df = pd.read_csv("/content/covid_toy - covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = 'mean')

# %%
df['fever'] = si.fit_transform(df[['fever']]) #### fit means learn the parametetr and transform means apply
# on that data .

# %%
x = df.drop(columns=['has_covid'])

# %%
x.shape
# Out:
# (100, 5)

# %%
# dff.isnull().sum()

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].map({'Male':0 , 'Female':1})

# %%
df.head(3)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60     NaN  103.0  Mild  Kolkata        No
# 1   27     NaN  100.0  Mild    Delhi       Yes
# 2   42     NaN  101.0  Mild    Delhi        No

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3032241535.py in <cell line: 0>()
# ----> 1 x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)
#
# NameError: name 'y' is not defined

# %%
print("Data shape :" , df.shape)
print("-----------------")
print("x data shape :" , x.shape)
print("x_train data shape: " , x_train.shape)
print("x_test data shape: " , x_test.shape)
print("---------------------")
print("y data shape :" , y.shape)
print("y_train data shape: " , y_train.shape)
print("y_test data shape: " , y_test.shape)
# Out:
# Data shape : (100, 6)
# -----------------
# x data shape : (100, 5)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3507813244.py in <cell line: 0>()
#       2 print("-----------------")
#       3 print("x data shape :" , x.shape)
# ----> 4 print("x_train data shape: " , x_train.shape)
#       5 print("x_test data shape: " , x_test.shape)
#       6 print("---------------------")
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# machine -----> works on Numbers .
#
# data -----> normal distribution .
