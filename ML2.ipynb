# %%
# machine -----> work on number .
# data ------> normal distribution
# standardization -------> mean = 0 , standard deviation = 1

# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv('/content/covid_toy - covid_toy.csv')
# df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
# df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# %%
# si = SimpleImputer(strategy = 'mean')

# %%
# df['fever'] = si.fit_transform(df[['fever']])

# %%
# df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
# df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
# df['gender'] = df['gender'].map({'Male':0 , 'Female':1})
# df['age'] = df['age'].map({'Mild':0 , 'Strong':1})
# df['cough'] = df['cough'].map({'Mild':0 , 'Strong':1})
# df['city'] = df['city'].map({'Bangalore':0 , 'Delhi':1})
# df['has_covid'] = df['has_covid'].map({'No':0 , 'Yes':1})

# %%
# df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0  NaN       0  103.0      0   NaN          0
# 1  NaN       0  100.0      0   1.0          1
# 2  NaN       0  101.0      0   1.0          0

# %%
# x = df.drop(columns = ['has_covid'])
# y = df['has_covid']

# %%
# from sklearn.model_selection import train_test_split

# %%
# x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state =42)

# %%
# print("Data shape :" , df.shape)
# print("-----------------")
# print("x data shape :" , x.shape)
# print("x_train data shape: " , x_train.shape)
# print("x_test data shape: " , x_test.shape)
# print("---------------------")
# print("y data shape :" , y.shape)
# print("y_train data shape: " , y_train.shape)
# print("y_test data shape: " , y_test.shape)
# Out:
# Data shape : (100, 6)
# -----------------
# x data shape : (100, 5)
# x_train data shape:  (80, 5)
# x_test data shape:  (20, 5)
# ---------------------
# y data shape : (100,)
# y_train data shape:  (80,)
# y_test data shape:  (20,)

# %%
# np.round(x_train.describe(),2)
# Out:
#        age  gender   fever  cough   city
# count  0.0   80.00   80.00  80.00  43.00
# mean   NaN    0.59  100.98   0.40   0.37
# std    NaN    0.50    1.93   0.49   0.49
# min    NaN    0.00   98.00   0.00   0.00
# 25%    NaN    0.00  100.00   0.00   0.00
# 50%    NaN    1.00  101.00   0.00   0.00
# 75%    NaN    1.00  102.00   1.00   1.00
# max    NaN    1.00  104.00   1.00   1.00

# %%
# now we will apply standardization

# %%
# from sklearn.preprocessing import StandardScaler

# %%
# sc = StandardScaler()

# %%
# x_train_sc = sc.fit_transform(x_train) # fit means learn the parmeter means apply on the data
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
# x_train_new = pd.DataFrame(x_train_sc , columns = x_train.columns)

# %%
# np.round(x_train_new.describe(),2)
# Out:
#        age  gender  fever  cough   city
# count  0.0   80.00  80.00  80.00  43.00
# mean   NaN   -0.00  -0.00  -0.00  -0.00
# std    NaN    1.01   1.01   1.01   1.01
# min    NaN   -1.19  -1.56  -0.82  -0.77
# 25%    NaN   -1.19  -0.51  -0.82  -0.77
# 50%    NaN    0.84   0.01  -0.82  -0.77
# 75%    NaN    0.84   0.53   1.22   1.30
# max    NaN    0.84   1.57   1.22   1.30

# %%
df = pd.read_csv('/content/click -.csv')
df.head(3)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     62.26   32     69481.85                172.83
# 1                     41.73   31     61840.26                207.17
# 2                     44.40   30     57877.15                172.83
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# 1                     Singapore  2016-01-16 17:56:05              0
# 2                    Guadeloupe  2016-06-29 10:50:45              0

# %%
df = df.drop(columns=['Ad Topic Line' , 'Timestamp' , 'City' ,'Country' ])

# %%
df.head(3)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Gender  \
# 0                     62.26   32     69481.85                172.83    Male
# 1                     41.73   31     61840.26                207.17    Male
# 2                     44.40   30     57877.15                172.83  Female
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0

# %%
df['Gender'] = df['Gender'].map({"Male":0 , "Female":1})

# %%
df.head(3)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Gender  \
# 0                     62.26   32     69481.85                172.83       0
# 1                     41.73   31     61840.26                207.17       0
# 2                     44.40   30     57877.15                172.83       1
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0

# %%
x = df.drop(columns=['Clicked on Ad'])
y = df['Clicked on Ad']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state =42)

# %%
# np.round(x_train.describe(),2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train_sc = sc.fit_transform(x_train)

# %%
x_train_new = pd.DataFrame(x_train_sc , columns = x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#        Daily Time Spent on Site      Age  Area Income  Daily Internet Usage  \
# count                   8000.00  8000.00      8000.00               8000.00
# mean                      -0.00    -0.00        -0.00                  0.00
# std                        1.00     1.00         1.00                  1.00
# min                       -1.85    -1.99        -2.97                 -1.77
# 25%                       -0.82    -0.82        -0.73                 -0.92
# 50%                       -0.14    -0.12         0.18                  0.03
# 75%                        0.96     0.70         0.60                  0.85
# max                        1.86     2.80         1.91                  2.27
#
#         Gender
# count  8000.00
# mean     -0.00
# std       1.00
# min      -1.08
# 25%      -1.08
# 50%       0.93
# 75%       0.93
# max       0.93
