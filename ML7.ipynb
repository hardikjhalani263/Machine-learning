# %%
# column transformer -----> in this we will creat template of our project .
# covid dataset
# df ----> x_train , x_test, y_test , y_train

# x_train ------> col1 , col2 , col3 , col4 ......

# categorical -----> Numerical ---> col.shape
# Numerical ------> col.shape

# np.concatenate(col1.shape , col2.shape ....coln.shape)

# when we apply columntrasformer ----> shape = without using column transfromer shape

# columntransformer(
#  'constant' , 'operatiojn_name/approach_name' , 'column_name'
# )

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/covid_toy - covid_toy.csv')
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
from sklearn.impute import SimpleImputer ### for fill missing value
from sklearn.preprocessing import OneHotEncoder  ##
from sklearn.preprocessing import OrdinalEncoder  ## encode

# %%
# df.isnull().sum()

# %%
x = df.drop(columns=['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
x_train.head(2)
# Out:
#     age  gender  fever cough     city
# 55   81  Female  101.0  Mild   Mumbai
# 88    5  Female  100.0  Mild  Kolkata

# %%
# we will apply operation one by one

# %%
#  adding simple imputer to fever column
si = SimpleImputer(strategy='mean')
X_train_fever = si.fit_transform(x_train[['fever']])
X_train_fever.shape
# Out:
# (80, 1)

# %%
# ordinal Encoding ----> cough
oe = OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough = oe.fit_transform(x_train[['cough']])
X_train_cough.shape
# Out:
# (80, 1)

# %%
# oneHotEncoding ----> gender , city
ohe = OneHotEncoder(drop='first' , sparse_output= False)
X_train_gender_city = ohe.fit_transform(x_train[['gender','city']])
X_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age
x_train_age = x_train.drop(columns=['gender','fever','cough','city']).values
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transformed = np.concatenate((x_train_age,X_train_fever,
                                      X_train_gender_city,
                                      X_train_cough),axis=1)

# %%
x_train_transformed.shape
# Out:
# (80, 7)

# %%
#  Now we will apply columntransform

# %%
from sklearn.compose import ColumnTransformer # this is how to import columnTransform

transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']) ,  # in a fever'column by the
    # help of SI we
    # fill missing values by mean , median , mode.
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']) , # by
    # this process
    # we encode our data .
    ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['gender','city'])
],remainder='passthrough') # remaninder = passthrough ==>
# it means rest all the columns remain same.

# %%
transformer.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
x_train
# Out:
#     age  gender  fever   cough       city
# 55   81  Female  101.0    Mild     Mumbai
# 88    5  Female  100.0    Mild    Kolkata
# 26   19  Female  100.0    Mild    Kolkata
# 42   27    Male  100.0    Mild      Delhi
# 69   73  Female  103.0    Mild      Delhi
# ..  ...     ...    ...     ...        ...
# 60   24  Female  102.0  Strong  Bangalore
# 71   75  Female  104.0  Strong      Delhi
# 14   51    Male  104.0    Mild  Bangalore
# 92   82  Female  102.0  Strong    Kolkata
# 51   11  Female  100.0  Strong    Kolkata
#
# [80 rows x 5 columns]

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
# ordinal Encoding ----> cough
oe = OrdinalEncoder(categories=[['Kolkata','Bangalore','Delhi', 'Mumbai']])
X_train_city = oe.fit_transform(x_train[['city']])
X_train_city.shape
# Out:
# (80, 1)

# %%
# oneHotEncoding ----> gender , city
ohe = OneHotEncoder(drop='first' , sparse_output= False)
X_train_gender_cough = ohe.fit_transform(x_train[['gender','cough']])
X_train_gender_cough.shape
# Out:
# (80, 2)

# %%
# Extracting Age
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transformed = np.concatenate((x_train_age,X_train_fever,
                                      X_train_gender_cough,
                                      X_train_cough),axis=1)

# %%
x_train_transformed.shape
# Out:
# (80, 5)
